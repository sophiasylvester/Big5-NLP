# %%
import pandas as pd
df = pd.read_csv('/home/sophia/ma_py/psych_lists/all_features_final.csv')
# df.info(verbose=True)
# df.iloc[:][17419:17443]

# %%
lst = df.columns.tolist()
print(lst)
# Out:
# ['author', 'type', 'temperament', 'introverted', 'intuitive', 'thinking', 'perceiving', 'subreddits_commented', 'subreddits_commented_mbti', 'num_comments', 'WC', 'Analytic', 'Clout', 'Authentic', 'Tone', 'WPS', 'Sixltr', 'Dic', 'function_x', 'pronoun', 'ppron', 'i_x', 'we_x', 'you_x', 'shehe', 'they_x', 'ipron', 'article', 'prep_x', 'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'compare', 'interrog', 'number_x', 'quant', 'affect', 'posemo', 'negemo', 'anx_x', 'anger', 'sad_x', 'social', 'family_x', 'friend_x', 'female', 'male', 'cogproc', 'insight', 'cause', 'discrep', 'tentat', 'certain_x', 'differ_x', 'percept', 'see_x', 'hear_x', 'feel_x', 'bio', 'body', 'health_x', 'sexual', 'ingest', 'drives', 'affiliation', 'achieve', 'power_x', 'reward', 'risk_x', 'focuspast', 'focuspresent', 'focusfuture', 'relativ', 'motion', 'space_x', 'time_x', 'work_x', 'leisure', 'home_x', 'money_x', 'relig', 'death_x', 'informal', 'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'AllPunc', 'P
# ...

# %%
idxlst = enumerate(lst)

# %%
for i in range(len(lst)):
    if i > 17418 and i < 17443:
        print(lst[i])
    elif i > 17444 and i < 17447:
        print(lst[i])
# Out:
# avg_mean_ser
# avg_mean_cnc
# avg_mean_fam
# avg_mean_img
# avg_mean_concretness
# avg_mean_valence
# avg_mean_arousal
# avg_mean_dominance
# avg_happiness_average
# mean_good_curse
# avg_emotion
# avg_polarity
# avg_social
# avg_moral
# avg_motionself
# avg_thought
# avg_color
# avg_tastesmell
# avg_tactile
# avg_visualform
# avg_auditory
# avg_space
# avg_quantity
# avg_time
# avg_colorado_norm
# avg_paivio_norm
